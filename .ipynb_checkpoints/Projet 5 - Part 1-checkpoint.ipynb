# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Import et traitement de la population par pays

# %%
df1 = pd.read_csv("data/population.csv")

# %%
df1
# Out:
#     Code Domaine              Domaine  Code Pays  \
# 0            FBS  Bilans Alimentaires          2
# 1            FBS  Bilans Alimentaires          2
# 2            FBS  Bilans Alimentaires        202
# 3            FBS  Bilans Alimentaires        202
# 4            FBS  Bilans Alimentaires          3
# 5            FBS  Bilans Alimentaires          3
# 6            FBS  Bilans Alimentaires          4
# 7            FBS  Bilans Alimentaires          4
# 8            FBS  Bilans Alimentaires         79
# 9            FBS  Bilans Alimentaires         79
# 10           FBS  Bilans Alimentaires          7
# 11           FBS  Bilans Alimentaires          7
# 12           FBS  Bilans Alimentaires          8
# 13           FBS  Bilans Alimentaires          8
# 14           FBS  Bilans Alimentaires        194
# 15           FBS  Bilans Alimentaires        194
# 16           FBS  Bilans Alimentaires          9
# 17           FBS  Bilans Alimentaires          9
# ...
