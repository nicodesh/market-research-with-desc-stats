# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import decomposition
from sklearn import preprocessing
import matplotlib.pyplot as plt

import sys
mypath="/Users/nicolasddb/Drive/190. Learning/001. Parcours Data Analyst OpenClassRooms/003. Projets/005. Projets n°5 - Produisez une étude de marché/Projet/mylib/"
sys.path.insert(0,mypath)

import easypca
from descstats import MyPlot
from descstats import MyPCA
from descstats import MyHier
from descstats import Univa

# %% [markdown]
# # 1. Import et traitement du dataframe principal

# %%
with open('data/main_df', 'rb') as f:
    my_unpickler = pickle.Unpickler(f)
    main_df = my_unpickler.load()

main_df = (
            main_df
                .copy()
    
                # Set country column as index
                .set_index('country')
    
                # Mean imputation
                .fillna(main_df.mean())
)
    
main_df.head(10)
# Out:
#                     pop_evol_ratio  kcal_total_capita_day  \
# country
# Arménie                  -0.019433                 2924.0
# Afghanistan               0.321682                 2087.0
# Albanie                  -0.020377                 3188.0
# Algérie                   0.188013                 3293.0
# Angola                    0.392387                 2474.0
# Antigua-et-Barbuda        0.111111                 2416.0
# Argentine                 0.091546                 3226.0
# Australie                 0.169899                 3278.0
# Autriche                  0.043355                 3770.0
# Bahamas                   0.193038                 2670.0
#
#                     proteins_total_capita_day  proteins_animal_ratio
# country
# Arménie                                 90.06               0.480235
# Afghanistan                             58.26               0.209749
# Albanie                                111.37               0.533537
# ...

# %% [markdown]
# # 3. Classification hiérarchique + ACP

# %%
# Hierarchical clustering
myhier = MyHier(main_df)
myhier.dendrogram()

# Compute 5 clusters from the hierarchical clustering
clusters = myhier.clusters(5)
centroids = myhier.centroids()
centroids_names = myhier.centroids_names

# Compute a PCA
mypca = MyPCA(main_df, n_components=4, clusters=clusters, centroids=centroids, centroids_names=centroids_names)

# Plot the screeplot of eigenvalues
mypca.scree()

# Plot the PCA with the clustering colors
mypca.scattercircle(1, 2, labelcircle=True)
mypca.scattercircle(1, 2, labelcircle=True, data_projected='centroids', markersize=100)
mypca.scattercircle(3, 4, labelcircle=True)
mypca.scattercircle(3, 4, labelcircle=True, data_projected='centroids', markersize=100)

# %% [markdown]
# ## Interprétations
#
# F1 : Faible croissance de la population <=> population bien nourrie
#
# F2 : ?
#
# F3 : Peu de protéïnes animales <=> population bien nourrie
#
# F4 : Beaucoup de protéïnes <=> population mal nourrie

# %%
tempdf = main_df.copy()
tempdf['cluster'] = clusters

myuni = Univa(main_df['proteins_animal_ratio'], filter_var=tempdf['cluster'])
myuni.describe()
# Out:
#                               proteins_animal_ratio           cluster=1  \
# Sample Size                                     178                  50
# Total                                            76                  11
# Min                              0.0984328226800493  0.0984328226800493
# Max                              0.7314635469125276  0.4327951760357908
# Mode                                              0                   0
# Mean                                              0                   0
# Median                                            0                   0
# Variance (σ²)                                  0.03                0.00
# Standard Deviation (σ)                         0.16                0.07
# Coefficient of variation (CV)                  0.37                0.16
# Skewness                                      -0.21                0.53
# Kurtosis                                      -1.06                0.16
#
# ...

# %%
display(mypca.centroids_projected)
display(mypca.centroids_names)
display(mypca.clusters)
# Out:
# array([[-2.06456476, -0.01634458,  0.19012917,  0.05664208],
#        [-1.70993476,  9.09258732, -1.48957821, -0.17519992],
#        [ 2.28591293,  0.21034782,  0.07756397,  0.12542608],
#        [ 0.40678492,  0.67968852,  0.7120538 , -0.04158116],
#        [ 0.31414156, -0.39567497, -0.34394672, -0.07834235]])
# array([1, 2, 3, 4, 5])
# array([5, 1, 3, 4, 1, 5, 3, 3, 3, 5, 5, 1, 5, 5, 5, 5, 4, 1, 5, 5, 5, 1,
#        3, 5, 1, 1, 1, 5, 4, 5, 1, 5, 4, 5, 4, 1, 3, 5, 5, 5, 5, 4, 5, 3,
#        5, 3, 3, 5, 1, 5, 5, 1, 3, 4, 1, 5, 3, 5, 1, 1, 5, 1, 5, 3, 5, 5,
#        3, 1, 1, 4, 1, 3, 3, 3, 1, 5, 5, 5, 4, 5, 1, 1, 1, 4, 4, 5, 1, 4,
#        1, 1, 3, 5, 1, 1, 5, 3, 4, 3, 4, 5, 5, 5, 4, 1, 5, 1, 1, 3, 5, 5,
#        5, 4, 5, 1, 1, 1, 3, 5, 5, 5, 5, 5, 5, 3, 3, 1, 1, 1, 3, 1, 3, 5,
#        5, 5, 5, 1, 4, 1, 1, 5, 5, 5, 3, 5, 5, 1, 1, 3, 5, 5, 5, 1, 5, 1,
#        5, 4, 4, 4, 2, 1, 3, 5, 3, 1, 5, 5, 5, 5, 1, 5, 1, 1, 3, 3, 5, 3,
#        5, 4], dtype=int32)

# %%
lol = np.ndarray(shape=(1,1))

# %%
lol
# Out:
# array([[5.e-324]])

# %%
np.append(lol,1)
# Out:
# array([5.e-324, 1.e+000])

# %%
lol = np.array([])
lol.shape
# Out:
# (0,)

# %%
np.append(lol,1)
# Out:
# array([1.])
